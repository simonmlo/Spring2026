# %% [markdown]
# # $$\text{Exercise 8 - Simon M. Løvdal}$$

# %%
from pathlib import Path
import numpy as np

folder = Path("Data/postProcessing/forceCoeffsIncompressible/0/coefficient.dat")

for file in folder.glob("*.dat"):
    A = np.loadtxt(file)
    print(file.name, A.shape)
