# %% [markdown]
# # $$\text{Exercise 8 - Simon M. Løvdal}$$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("ContinousData/coeffRe1000.dat", sep=r"\s+")

time = df['Time']

liftCoeff = df['Cl']

plt.plot(time, liftCoeff)
plt.grid()
plt.tight_layout()
plt.show()
