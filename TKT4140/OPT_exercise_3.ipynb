# %% [markdown]
# # $$\text{Simon M. Løvdal}$$
# ### $$\text{The second Mandatory Assignment in TKT4140}$$

# %% [markdown]
# # OPT python exercise 3

# %% [markdown]
# In this exercise we want to the minimize the following cost function $f(x,y)$
#
# $$ f(x,y) = \left(x-\sin{\left(2.x.y+x \right)} \right)^2 + \left(y-\cos\left(x.y\right)\right)^2$$
#
# The variables $x$ and $y$ are bounded and defined by:
#
# $$ -2\le x \le 6$$
# $$ -3\le y \le 1$$

# %% [markdown]
# In this exercice you should:
# 1. Define a function to compute the cost function $f$ to be used within the optimization packages.
# 2. Plot the cost function $f$ as a filled contour plot alongside a colorbar within the bounds define earlier.
# 3. Using the starting points $x_0=6.0$ and $y_0=0.0$ and the SLSQP algorithm find the optimal solution of the defined problem.
# 4. Plot both the initial guess and the optimized value of the parameters onto the countour plot of the cost function.
# 5. Using the starting points $x_0=6.0$ and $y_0=0.5$ and the SLSQP algorithm find the optimal solution of the defined problem.
# 6. Plot both the initial guess and the optimized value of the parameters onto the countour plot of the cost function. Can you comment on what you observe?
# 7. Repeat the optimization problem using the basin hopping algorithm. You can use the two starting points defined in questions 3 and 4. In the basin hopping algorithm you can use 10 iterations.
# 8. Repeat question 7 using 20 iterations instead of 10.
# 9. Apply the differential evolution algorithms to find the global minima of the cost function.
# 10. Discuss the numerical cost (number of iterations and function evaluations) associated with the different algorithms used in 5, 8 and 9. Can you comment on what you observe?

# %% [markdown]
# ## $$\text{Start of Assignment}$$

# %% [markdown]
# ### $\text{Preliminaries}$

# %% [markdown]
# ### $\text{(1) - Cost Function}$
# Define a function to compute the cost function $f$ to be used within the optimization packages.

# %% [markdown]
# ### $\text{(2) - Contour Plot of Cost Function}$
# Plot the cost function $f$ as a filled contour plot alongside a colorbar within the bounds define earlier.

# %% [markdown]
# ### $\text{(3) - SLSQP Algorithm (find the optimal solution)}$
# Using the starting points $x_0=6.0$ and $y_0=0.0$ and the SLSQP algorithm find the optimal solution of the defined problem.

# %% [markdown]
# ### $\text{(4) - Plot initial guess and optimized value}$
# Plot both the initial guess and the optimized value of the parameters onto the countour plot of the cost function.

# %% [markdown]
# ### $\text{(5) - Different initial guesses}$
# Using the starting points $x_0=6.0$ and $y_0=0.5$ and the SLSQP algorithm find the optimal solution of the defined problem.

# %% [markdown]
# ### $\text{(6) - What do we observe?}$
# Plot both the initial guess and the optimized value of the parameters onto the countour plot of the cost function. Can you comment on what you observe?

# %% [markdown]
# ### $\text{(7) - Basin Hopping Algorithm}$
# Repeat the optimization problem using the basin hopping algorithm. You can use the two starting points defined in questions 3 and 4. In the basin hopping algorithm you can use 10 iterations.

# %% [markdown]
# ### $\text{(8) - More iterations}$
# Repeat question 7 using 20 iterations instead of 10.

# %% [markdown]
# ### $\text{(9) - Differential Evolution Algorithm}$
# Apply the differential evolution algorithms to find the global minima of the cost function.

# %% [markdown]
# ### $\text{(10) - Discussion}$
# Discuss the numerical cost (number of iterations and function evaluations) associated with the different algorithms used in 5, 8 and 9. Can you comment on what you observe?
